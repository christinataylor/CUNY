# %%
"""from IPython import parallel
clients = parallel.Client()
clients.block = True
print clients.ids

dview = clients.direct_view()

# %px import numpy
# %px n = numpy.random.random(3)
# %px print n

n = dview.gather('n')
print n"""

# %%
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('apple2011.csv', index_col = "Date")
df.rename(columns={'Unnamed: 2': 'pc'}, inplace=True)
df.pc[0] = float('NaN')
for i in np.arange(1,len(df.pc)):
    df.pc[i] = float(df.pc[i])

# %%
biglist = []

for j in np.arange(0,10000):
    
    lastprice = df.Last[len(df.Last)-1]

    montecarlolist = []

    for i in np.arange(0,20):
        montecarlolist.append(np.random.normal(df.pc.mean(), df.pc.std()))

    montecarlolist = np.array(montecarlolist)
    
    for i in np.arange(0,len(montecarlolist)):
        lastprice = lastprice * (1+montecarlolist[i])
    
    biglist.append(lastprice)

biglist = np.array(biglist)

plt = hist(biglist, bins=30)

axvline(df.Last[len(df.Last)-1], color='r', linestyle='dashed', linewidth=2)

axvline(np.percentile(biglist, 1), color='g', linestyle='dashed', linewidth =2)

# %%
biglist
var = df.Last[len(df.Last)-1] - np.percentile(biglist, 1)

print 'With the final share price of $' + str(df.Last[len(df.Last)-1]) + ' represented by the red line in the above histogram, the calculated VaR per share over 20 days is $' + str(var)
# Out:
# With the final share price of $405.0 represented by the red line in the above histogram, the calculated VaR per share over 20 days is $59.9539836008

# %%
setupsingle = """
import pandas as pd
import numpy as np
from IPython import parallel

df = pd.read_csv('apple2011.csv', index_col = "Date")
df.rename(columns={'Unnamed: 2': 'pc'}, inplace=True)
df.pc[0] = float('NaN')
for i in np.arange(1,len(df.pc)):
    df.pc[i] = float(df.pc[i])

def singletest(df):
    biglist = []

    for j in np.arange(0,10000):
    
        lastprice = df.Last[len(df.Last)-1]

        montecarlolist = []

        for i in np.arange(0,20):
            montecarlolist.append(np.random.normal(df.pc.mean(), df.pc.std()))

        montecarlolist = np.array(montecarlolist)
    
        for i in np.arange(0,len(montecarlolist)):
            lastprice = lastprice * (1+montecarlolist[i])
    
        biglist.append(lastprice)

    biglist = np.array(biglist)
    
    return df.Last[len(df.Last)-1] - np.percentile(biglist, 1)

def multitest(df):
    clients = parallel.Client()
    clients.block = True
    
    dview = clients.direct_view()
    
    biglist = []
    
    # %px import pandas as pd
    # %px import 

"""

# %%
end1 = (len(df.Last)/4)-1
begin2 = (len(df.Last)/4)-1
end2 = (len(df.Last)/2)-1
begin3 = (len(df.Last)/2)-1
end3 = (3*len(df.Last)/4)-1
begin4 = (3*len(df.Last)/4)-1
end4 = len(df.Last)


df1 = pd.DataFrame({'Last' : df.Last[0:end1],
                    'pc' : df.pc[0:end1]},
                   index = df.index[0:end1])

df2 = pd.DataFrame({'Last' : df.Last[begin2:end2],
                    'pc' : df.pc[begin2:end2]},
                   index = df.index[begin2:end2])

df3 = pd.DataFrame({'Last' : df.Last[begin3:end3],
                    'pc' : df.pc[begin3:end3]},
                   index = df.index[begin3:end3])

df4 = pd.DataFrame({'Last' : df.Last[begin4:end4],
                    'pc' : df.pc[begin4:end4]},
                   index = df.index[begin4:end4])
#df.Last[0:(len(df.Last)/4)-1]

"""
print end1
print begin2
print end2
print begin3
print end3
print begin4
print end4

"""

df4
# Out:
#                Last           pc
# Date
# 9/30/2011   381.320  -0.02368333
# 10/3/2011   374.600  -0.01762299
# 10/4/2011   372.500  -0.00560598
# 10/5/2011   378.250   0.01543624
# 10/6/2011   377.370 -0.002326504
# 10/7/2011   369.800  -0.02005989
# 10/10/2011  388.810   0.05140616
# 10/11/2011  400.290   0.02952599
# 10/12/2011  402.190  0.004746559
# 10/13/2011  408.430   0.01551505
# 10/14/2011  422.000   0.03322479
# 10/17/2011  419.990 -0.004763033
# 10/18/2011  422.240   0.00535727
# 10/19/2011  398.620  -0.05593975
# 10/20/2011  395.310 -0.008303648
# 10/21/2011  392.870 -0.006172371
# 10/24/2011  405.770   0.03283529
# 10/25/2011  397.770   -0.0197156
# 10/26/2011  400.600  0.007114664
# 10/27/2011  404.690   0.01020968
# 10/28/2011  404.950  0.000642467
# 10/31/2011  404.780 -0.000419805
# 11/1/2011   396.510  -0.02043085
# 11/2/2011   397.410  0.002269804
# 11/3/2011   403.070   0.01424222
# 11/4/2011   400.240 -0.007021113
# 11/7/2011   399.730 -0.001274235
# 11/8/2011   406.230   0.01626098
# 11/9/2011   395.280  -0.02695517
# 11/10/2011  385.220  -0.02545031
# ...             ...          ...
# 11/17/2011  377.410  -0.01912831
# 11/18/2011  374.940 -0.006544607
# 11/21/2011  369.010  -0.01581586
# 11/22/2011  376.510   0.02032465
# 11/23/2011  366.990  -0.02528485
# 11/25/2011  363.570 -0.009319055
# 11/28/2011  376.120    0.0345188
# 11/29/2011  373.200  -0.00776348
# 11/30/2011  382.200   0.02411576
# 12/1/2011   387.930   0.01499215
# 12/2/2011   389.700  0.004562679
# 12/5/2011   393.010  0.008493713
# 12/6/2011   390.950 -0.005241597
# 12/7/2011   389.090 -0.004757642
# 12/8/2011   390.660  0.004035056
# 12/9/2011   393.620  0.007576921
# 12/12/2011  391.840 -0.004522128
# 12/13/2011  388.810 -0.007732748
# 12/14/2011  380.190  -0.02217021
# 12/15/2011  378.940  -0.00328783
# 12/16/2011  381.020  0.005488996
# 12/19/2011  382.210  0.003123196
# 12/20/2011  395.950   0.03594882
# 12/21/2011  396.445  0.001250158
# 12/22/2011  398.550   0.00530969
# 12/23/2011  403.330   0.01199348
# 12/27/2011  406.530   0.00793395
# 12/28/2011  402.640  -0.00956879
# 12/29/2011  405.120  0.006159348
# 12/30/2011  405.000 -0.000296209
#
# [64 rows x 2 columns]

# %%
def multitest(df):
    clients = parallel.Client()
    clients.block = True
    
    dview = clients.direct_view()
    
    biglist = []
    
    # %px import pandas as pd
    # %px import numpy as np
    
    # %px biglist = []
    
    # %px for j in np.arange(0,10000/4):
        
        # %px lastprice = df.Last[len(df.Last)-1]
        
        # %px montecarlolist = []
        
        # %px for i in np.arange(0,20):
            # %px montecarlolist.append(np.random.normal(df.pc.mean(), df.pc.std()))
        
        # %px montecarlolist = np.array(montecarlolist)
        
        # %px for i in np.arange(0, len(montecarlolist)):
            # %px lastprice = lastprice * (1+montecarlolist[i])
        
        biglist.append(lastprice)
    
    biglist = np.array(biglist)

    
    
    
biglist = []

for j in np.arange(0,10000):
    
    lastprice = df.Last[len(df.Last)-1]

    montecarlolist = []

    for i in np.arange(0,20):
        montecarlolist.append(np.random.normal(df.pc.mean(), df.pc.std()))

    montecarlolist = np.array(montecarlolist)
    
    for i in np.arange(0,len(montecarlolist)):
        lastprice = lastprice * (1+montecarlolist[i])
    
    biglist.append(lastprice)

biglist = np.array(biglist)
# Out:
#   File "<ipython-input-48-edd9087140d4>", line 16
#     get_ipython().magic(u'px lastprice = df.Last[len(df.Last)-1]')
#     ^
# IndentationError: unexpected indent

# %%
from IPython import parallel
clients = parallel.Client()
clients.block = True
print clients.ids

dview = clients.direct_view()

# %px import numpy
# %px n = []
# %px for i in arange(1,4):
# %px n.append(i)
# %px print n

n = dview.gather('n')
print n
# Out:
#   File "<ipython-input-61-024fabeaf24f>", line 11
#     n.append(i)
#     ^
# IndentationError: unexpected indent

# %%
np.arange(1,3)
# Out:
# array([1, 2])
